# %% [markdown]
# #Weight

# %%
import pandas as pd
import numpy as np

# %%
weight = pd.read_csv("/content/drive/MyDrive/week_8/weightLogInfo_merged.csv")

# %%
weight.head(5)
# Out:
#            Id                   Date    WeightKg  WeightPounds   Fat  \
# 0  1503960366   5/2/2016 11:59:59 PM   52.599998    115.963147  22.0
# 1  1503960366   5/3/2016 11:59:59 PM   52.599998    115.963147   NaN
# 2  1927972279   4/13/2016 1:08:52 AM  133.500000    294.317120   NaN
# 3  2873212765  4/21/2016 11:59:59 PM   56.700001    125.002104   NaN
# 4  2873212765  5/12/2016 11:59:59 PM   57.299999    126.324875   NaN
#
#          BMI  IsManualReport          LogId
# 0  22.650000            True  1462233599000
# 1  22.650000            True  1462319999000
# 2  47.540001           False  1460509732000
# 3  21.450001            True  1461283199000
# 4  21.690001            True  1463097599000

# %%
weight["Date"] = pd.to_datetime(weight["Date"]).dt.strftime("%m/%d/%Y")
weight["Date"] = weight["Date"].str.replace("-","/")
# Out:
# <ipython-input-12-f9abaa945c18>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   weight["Date"] = pd.to_datetime(weight["Date"]).dt.strftime("%m/%d/%Y")

# %%
weight.isnull().sum()
# Out:
# Id                 0
# Date               0
# WeightKg           0
# WeightPounds       0
# Fat               65
# BMI                0
# IsManualReport     0
# LogId              0
# dtype: int64

# %%
del weight["Fat"]

# %%
weight.head(5)
# Out:
#            Id        Date    WeightKg  WeightPounds        BMI  \
# 0  1503960366  05/02/2016   52.599998    115.963147  22.650000
# 1  1503960366  05/03/2016   52.599998    115.963147  22.650000
# 2  1927972279  04/13/2016  133.500000    294.317120  47.540001
# 3  2873212765  04/21/2016   56.700001    125.002104  21.450001
# 4  2873212765  05/12/2016   57.299999    126.324875  21.690001
#
#    IsManualReport          LogId
# 0            True  1462233599000
# 1            True  1462319999000
# 2           False  1460509732000
# 3            True  1461283199000
# 4            True  1463097599000

# %%
weight.isna().sum()
# Out:
# Id                0
# Date              0
# WeightKg          0
# WeightPounds      0
# BMI               0
# IsManualReport    0
# LogId             0
# dtype: int64

# %%
weight.to_csv("/content/drive/MyDrive/omer_8/Weight_Data.csv")

# %% [markdown]
# #Heart

# %%
import pandas as pd
import numpy as np

# %%
heart = pd.read_csv("/content/drive/MyDrive/week_8/heartrate_seconds_merged.csv")

# %%
heart.head(5)
# Out:
#            Id                  Time  Value
# 0  2022484408  4/12/2016 7:21:00 AM     97
# 1  2022484408  4/12/2016 7:21:05 AM    102
# 2  2022484408  4/12/2016 7:21:10 AM    105
# 3  2022484408  4/12/2016 7:21:20 AM    103
# 4  2022484408  4/12/2016 7:21:25 AM    101

# %%
heart.isna().sum()
# Out:
# Id       0
# Time     0
# Value    0
# dtype: int64

# %%
heart["Time"] = pd.to_datetime(heart["Time"]).dt.strftime("%m/%d/%Y")
heart["Time"] = heart["Time"].str.replace("-","/")

# %%
heart.head(10)
# Out:
#            Id        Time  Value
# 0  2022484408  04/12/2016     97
# 1  2022484408  04/12/2016    102
# 2  2022484408  04/12/2016    105
# 3  2022484408  04/12/2016    103
# 4  2022484408  04/12/2016    101
# 5  2022484408  04/12/2016     95
# 6  2022484408  04/12/2016     91
# 7  2022484408  04/12/2016     93
# 8  2022484408  04/12/2016     94
# 9  2022484408  04/12/2016     93

# %%
heart.to_csv("/content/drive/MyDrive/omer_8/Heart_Data.csv")
